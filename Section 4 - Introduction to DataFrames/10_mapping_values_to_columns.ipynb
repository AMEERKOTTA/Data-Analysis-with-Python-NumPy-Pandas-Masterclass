# %% [markdown]
# ### MAPPING VALUES TO COLUMNS
#
# + The `.map()` method will map the values to a Column or an Entire Dataframe.
# + Can pass dictionary with existing values as keys.
# + And new values as Values.
# + You can apply lambda functions as well.
#
# Column Creation with `.assign` method.
#
# + The assign method creates multiple columns and return Dataframe.
# + This can be chained with Other Daat Processing Steps.

# %%
import pandas as pd
import numpy as np

# %%
product_df = pd.read_csv("product.csv")
product_df
mapping_dict = {
    "Diary" : "Non-Vegan",
    "Vegetables" : "Vegan",
    "Fruits" : "Vegan"
}

product_df["Vegan??"] = product_df["PRODUCT_ID"].map(mapping_dict)
product_df
# Out:
#        PRODUCT_ID  MANUFACTURER    DEPARTMENT     BRAND  \
# 0           25671             2       GROCERY  National
# 1           26081             2  MISC. TRANS.  National
# 2           26093            69        PASTRY   Private
# 3           26190            69       GROCERY   Private
# 4           26355            69       GROCERY   Private
# ...           ...           ...           ...       ...
# 92348    18293142          6384       DRUG GM  National
# 92349    18293439          6393       DRUG GM  National
# 92350    18293696          6406       DRUG GM  National
# 92351    18294080          6442       DRUG GM  National
# 92352    18316298           764       GROCERY  National
#
#                  COMMODITY_DESC           SUB_COMMODITY_DESC  \
# 0                      FRZN ICE          ICE - CRUSHED/CUBED
# 1      NO COMMODITY DESCRIPTION  NO SUBCOMMODITY DESCRIPTION
# 2                         BREAD         BREAD:ITALIAN/FRENCH
# 3          FRUIT - SHELF STABLE                  APPLE SAUCE
# 4                 COOKIES/CONES            SPECIALTY COOKIES
# ...                         ...                          ...
# 92348                 BOOKSTORE              PAPERBACK BOOKS
# 92349                 BOOKSTORE            CHILDRENS LOW END
# 92350                 BOOKSTORE        PAPERBACK BEST SELLER
# 92351                 BOOKSTORE              PAPERBACK BOOKS
# 92352              PAPER TOWELS       PAPER TOWELS & HOLDERS
#
#       CURR_SIZE_OF_PRODUCT Vegan??
# 0                    22 LB     NaN
# 1                              NaN
# 2                              NaN
# 3                    50 OZ     NaN
# 4                    14 OZ     NaN
# ...                    ...     ...
# 92348                          NaN
# 92349                          NaN
# 92350                          NaN
# 92351                          NaN
# 92352                          NaN
#
# [92353 rows x 8 columns]

# %%
retail = pd.read_csv("retail_2016_2017.csv")
retail.loc[:, "family"].value_counts()
# Out:
# HARDWARE                      31968
# HOME AND KITCHEN II           31968
# FROZEN FOODS                  31968
# CLEANING                      31968
# SCHOOL AND OFFICE SUPPLIES    31968
# HOME APPLIANCES               31968
# PLAYERS AND ELECTRONICS       31968
# AUTOMOTIVE                    31968
# PREPARED FOODS                31968
# POULTRY                       31968
# GROCERY I                     31968
# BEVERAGES                     31968
# PERSONAL CARE                 31968
# BREAD/BAKERY                  31968
# LADIESWEAR                    31968
# LAWN AND GARDEN               31968
# GROCERY II                    31968
# PRODUCE                       31968
# BABY CARE                     31968
# HOME CARE                     31968
# LIQUOR,WINE,BEER              31968
# LINGERIE                      31968
# DAIRY                         31968
# DELI                          31968
# PET SUPPLIES                  31968
# SEAFOOD                       31968
# MAGAZINES                     31968
# BOOKS                         31968
# MEATS                         31968
# HOME AND KITCHEN I            31968
# EGGS                          31968
# BEAUTY                        31968
# CELEBRATION                   31968
# Name: family, dtype: int64

# %%
product_category_dict = {
    "PRODUCE" : "Grocery",
    "POULTRY" : "Grocery",
    "GROCERY I" : "Grocery",
    "GROCERY II" : "Grocery",
    "EGGS" : "Grocery"
}

# %%
retail.loc[:, "family"].map(product_category_dict)
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#             ...
# 1054939    Grocery
# 1054940        NaN
# 1054941    Grocery
# 1054942        NaN
# 1054943        NaN
# Name: family, Length: 1054944, dtype: object

# %%
retail.loc[:, "family"].map(product_category_dict).value_counts()
# Out:
# Grocery    159840
# Name: family, dtype: int64

# %%
retail.loc[:, "family"].map(product_category_dict).value_counts(dropna = False)
# Out:
# NaN        895104
# Grocery    159840
# Name: family, dtype: int64

# %%
retail

retail.assign(
        tax_amount = (retail["sales"] * 0.18).round(2),
        on_promotion_flag = (retail["onpromotion"] > 0),
        year = (retail["date"].str[:4].astype("int")),
        month = (retail["date"].str[5:7].astype("int")),
        day = (retail["date"].str[8:].astype("int"))
).query("year < 2020")
# Out:
#               id        date  store_nbr                      family     sales  \
# 0        1945944  2016-01-01          1                  AUTOMOTIVE     0.000
# 1        1945945  2016-01-01          1                   BABY CARE     0.000
# 2        1945946  2016-01-01          1                      BEAUTY     0.000
# 3        1945947  2016-01-01          1                   BEVERAGES     0.000
# 4        1945948  2016-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 1054939  3000883  2017-08-15          9                     POULTRY   438.133
# 1054940  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 1054941  3000885  2017-08-15          9                     PRODUCE  2419.729
# 1054942  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 1054943  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion  tax_amount  on_promotion_flag  year  month  day
# 0                  0        0.00              False  2016      1    1
# 1                  0        0.00              False  2016      1    1
# 2                  0        0.00              False  2016      1    1
# 3                  0        0.00              False  2016      1    1
# 4                  0        0.00              False  2016      1    1
# ...              ...         ...                ...   ...    ...  ...
# 1054939            0       78.86              False  2017      8   15
# 1054940            1       27.82               True  2017      8   15
# 1054941          148      435.55               True  2017      8   15
# 1054942            8       21.78               True  2017      8   15
# 1054943            0        2.88              False  2017      8   15
#
# [1054944 rows x 11 columns]

# %%
retail
sample_df = retail.sample(5, random_state = 82)
sample_df

sample_df.assign(
    on_promotion_flag = sample_df["onpromotion"] > 0,
    family_abbreviation = sample_df["family"].str[:3],
    gst_amount = sample_df["sales"] * 0.18,
    year = sample_df["date"].str[:4],
    month = sample_df["date"].str[5:7],
    day = sample_df["date"].str[8:]
)
# Out:
#              id        date  store_nbr           family    sales  onpromotion  \
# 889389  2835333  2017-05-15         14      CELEBRATION   15.000            0
# 157108  2103052  2016-03-29         17          POULTRY  317.235            0
# 153391  2099335  2016-03-27         13         CLEANING  536.000            0
# 403863  2349807  2016-08-14         40             DELI  262.000            5
# 148520  2094464  2016-03-24         26  LAWN AND GARDEN    0.000            0
#
#         on_promotion_flag family_abbreviation  gst_amount  year month day
# 889389              False                 CEL      2.7000  2017    05  15
# 157108              False                 POU     57.1023  2016    03  29
# 153391              False                 CLE     96.4800  2016    03  27
# 403863               True                 DEL     47.1600  2016    08  14
# 148520              False                 LAW      0.0000  2016    03  24
