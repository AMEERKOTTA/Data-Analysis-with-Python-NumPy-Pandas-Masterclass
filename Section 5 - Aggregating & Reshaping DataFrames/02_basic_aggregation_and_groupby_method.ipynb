# %% [markdown]
# ### BASIC AGGREGATION AND GROUPBY METHOD
#
# + We can use the basic Aggregations.
# + `.sum(), .mean(), .std()`  etc

# %%
import pandas as pd
import numpy as np

# %%
pl = pd.read_csv("2021-2022.csv")
pl.head()
# Out:
#   Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1  E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2  E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3  E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4  E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
#
#    HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# 2     0  ...     1.62  0.25      1.79      2.15   1.81   2.14     1.82
# 3     0  ...     1.94 -1.50      2.05      1.75   2.12   1.81     2.16
# 4     1  ...     1.67 -0.50      2.05      1.88   2.05   1.88     2.08
#
#    MaxCAHA  AvgCAHH  AvgCAHA
# 0     2.17     1.80     2.09
# ...

# %%
df = pl[["Date", "Time", "HomeTeam", "AwayTeam", "FTHG", "FTAG"]]
df.head()
df.rename(columns = {"FTHG" : "Home Goals", "FTAG" : "Away Goals"}, inplace = True)
df.head()
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#          Date   Time    HomeTeam        AwayTeam  Home Goals  Away Goals
# 0  13/08/2021  20:00   Brentford         Arsenal           2           0
# 1  14/08/2021  12:30  Man United           Leeds           5           1
# 2  14/08/2021  15:00     Burnley        Brighton           1           2
# 3  14/08/2021  15:00     Chelsea  Crystal Palace           3           0
# 4  14/08/2021  15:00     Everton     Southampton           3           1

# %%
#df

# %%
df.sum()
# Out:
# Date          13/08/202114/08/202114/08/202114/08/202114/08/...
# Time          20:0012:3015:0015:0015:0015:0015:0017:3014:001...
# HomeTeam      BrentfordMan UnitedBurnleyChelseaEvertonLeices...
# AwayTeam      ArsenalLeedsBrightonCrystal PalaceSouthamptonW...
# Home Goals                                                  575
# Away Goals                                                  496
# dtype: object

# %%
df.mean()
# Out:
# Home Goals    1.513158
# Away Goals    1.305263
# dtype: float64

# %%
df.loc[:, ["Home Goals", "Away Goals"]].mean()
# Out:
# Home Goals    1.513158
# Away Goals    1.305263
# dtype: float64

# %%
df.loc[:, ["Home Goals", "Away Goals"]].std()
# Out:
# Home Goals    1.326545
# Away Goals    1.258836
# dtype: float64

# %%
df.loc[:, ["Home Goals", "Away Goals"]].var()
# Out:
# Home Goals    1.759721
# Away Goals    1.584669
# dtype: float64

# %%
df.loc[:, ["Home Goals", "Away Goals"]].describe()
# Out:
#        Home Goals  Away Goals
# count  380.000000  380.000000
# mean     1.513158    1.305263
# std      1.326545    1.258836
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    2.000000
# max      7.000000    6.000000

# %% [markdown]
# ### GROUPBY METHOD
#
# + Grouping Dataframes will allow you to aggregate the data at a different level.
# + To group data, use the `.groupby()` method, and specify a column to groupby.
# + The grouped column becomes the index by default.

# %%
## reading teh retail dataset
retail = pd.read_csv("retail_2016_2017.csv")
retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944  2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
## groupby "family"
small_retail = retail.groupby("family")
small_retail

## perform some kind of aggregation on some column
retail.groupby("family")["sales"].sum().head()
# Out:
# family
# AUTOMOTIVE       226139.0
# BABY CARE          7903.0
# BEAUTY           166189.0
# BEVERAGES     105700279.0
# BOOKS              6438.0
# Name: sales, dtype: float64

# %%
## perform some kind of aggregation on some column
retail.groupby("family")[["sales"]].mean().head()
# Out:
#                   sales
# family
# AUTOMOTIVE     7.073918
# BABY CARE      0.247216
# BEAUTY         5.198605
# BEVERAGES   3306.440159
# BOOKS          0.201389

# %%
df.head()
df.groupby(["HomeTeam"])[["Home Goals"]].sum()
# Out:
#                 Home Goals
# HomeTeam
# Arsenal                 35
# Aston Villa             29
# Brentford               22
# Brighton                19
# Burnley                 18
# Chelsea                 37
# Crystal Palace          27
# Everton                 27
# Leeds                   19
# Leicester               34
# Liverpool               49
# Man City                58
# Man United              32
# Newcastle               26
# Norwich                 12
# Southampton             23
# Tottenham               38
# Watford                 17
# West Ham                33
# Wolves                  20

# %%
df.groupby(["HomeTeam"])[["Home Goals"]].sum().sort_values(by = "Home Goals", ascending = False).head()
# Out:
#            Home Goals
# HomeTeam
# Man City           58
# Liverpool          49
# Tottenham          38
# Chelsea            37
# Arsenal            35

# %%
df.groupby(["AwayTeam"])[["Away Goals"]].sum().sort_values(by = "Away Goals", ascending = False).head()
# Out:
#            Away Goals
# AwayTeam
# Liverpool          45
# Man City           41
# Chelsea            39
# Tottenham          31
# Leicester          28

# %%
## reading the transactions data
transactions = pd.read_csv("transactions.csv")
transactions.head()
transactions.groupby("store_nbr")[["transactions"]].sum().sort_values(by = "transactions", ascending = False).head(10)
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %% [markdown]
# ### Grouping by Multiple Columns
#
# + This can be done by Passing the list of Columns to the groupby method.
# + This create a multi index object.

# %%
retail = pd.read_csv("retail_2016_2017.csv")
retail.head()
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0  1945944  2016-01-01          1  AUTOMOTIVE    0.0            0
# 1  1945945  2016-01-01          1   BABY CARE    0.0            0
# 2  1945946  2016-01-01          1      BEAUTY    0.0            0
# 3  1945947  2016-01-01          1   BEVERAGES    0.0            0
# 4  1945948  2016-01-01          1       BOOKS    0.0            0

# %%
retail.groupby(["family","store_nbr"], as_index = False)[["sales"]].sum().loc[:100].query("family == 'AUTOMOTIVE'")
# Out:
#         family  store_nbr   sales
# 0   AUTOMOTIVE          1  2524.0
# 1   AUTOMOTIVE          2  3918.0
# 2   AUTOMOTIVE          3  6790.0
# 3   AUTOMOTIVE          4  2565.0
# 4   AUTOMOTIVE          5  3667.0
# 5   AUTOMOTIVE          6  3442.0
# 6   AUTOMOTIVE          7  3031.0
# 7   AUTOMOTIVE          8  3225.0
# 8   AUTOMOTIVE          9  7695.0
# 9   AUTOMOTIVE         10  1772.0
# 10  AUTOMOTIVE         11  4387.0
# 11  AUTOMOTIVE         12  3507.0
# 12  AUTOMOTIVE         13  3499.0
# 13  AUTOMOTIVE         14  2858.0
# 14  AUTOMOTIVE         15  1874.0
# 15  AUTOMOTIVE         16  3007.0
# 16  AUTOMOTIVE         17  5067.0
# 17  AUTOMOTIVE         18  2006.0
# 18  AUTOMOTIVE         19  4641.0
# 19  AUTOMOTIVE         20  4555.0
# 20  AUTOMOTIVE         21  6053.0
# 21  AUTOMOTIVE         22  3092.0
# 22  AUTOMOTIVE         23  1272.0
# 23  AUTOMOTIVE         24  2234.0
# 24  AUTOMOTIVE         25  1745.0
# 25  AUTOMOTIVE         26  2755.0
# ...

# %%
## transactions
transactions
## adding a column "month" to transactions
tr_df = transactions.assign(
    month = transactions["date"].str[5:7].astype("int")
)
tr_df.head()
# Out:
#          date  store_nbr  transactions  month
# 0  2013-01-01         25           770      1
# 1  2013-01-02          1          2111      1
# 2  2013-01-02          2          2358      1
# 3  2013-01-02          3          3487      1
# 4  2013-01-02          4          1922      1

# %%
tr_df.groupby(["store_nbr","month"])[["transactions"]].sum().sort_values(by = ["month","transactions"], ascending = [True, False])
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]
